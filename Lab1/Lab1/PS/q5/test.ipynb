# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("24b1094_24b1086.csv")
df2 = pd.read_csv("24B0919_24B0979.csv")
df3 = pd.read_csv("test_X.csv")
np.mean((df1['y']-df2['y'])**2)
# Out:
# np.float64(5.17475814834349)

# %%
diff = df1['y']-df2['y']
small = np.where(abs(df3['x8'])<5, diff, 0)

# %%
df3['x8']
# Out:
# 0       8.092791
# 1       0.959200
# 2      -0.232031
# 3      -1.249826
# 4       0.531389
#           ...
# 1495    0.670827
# 1496   -0.099060
# 1497    0.618563
# 1498   -1.056360
# 1499   -0.351057
# Name: x8, Length: 1500, dtype: float64

# %%
small
# Out:
# array([0.        , 1.5946561 , 1.99675864, ..., 0.03666794, 1.41651738,
#        0.65700968], shape=(1500,))

# %%
np.mean(small**2)
# Out:
# np.float64(5.028218925243659)
